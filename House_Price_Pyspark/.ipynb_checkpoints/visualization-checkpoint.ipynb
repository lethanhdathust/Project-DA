# %%
# # !pip3 install setuptools
# !pip install pycaret
# !pip install missingno

# %%
import json
from tqdm import tqdm
# import cloudscraper
import pandas as pd
import missingno as msno 
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
import numpy as np
import datetime
import scipy.stats

pd.set_option('display.float_format', '{:.6f}'.format)

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',100)

# %%
df_raw= pd.read_csv('data.csv')

# %% [markdown]
# #### Data cleaning

# %%
df_raw = df_raw.drop(columns=['pty_characteristics','price_million_per_m2','shop_alias','date' ,'shop.alias', 'shop.status', 'shop.name', 'shop.address', 'shop.profileImageUrl', 'shop.createdDate', 'shop.modifiedDate', 'shop.urls', 'shop.shopsCategoriesRelationships', 'ad_id', 'list_id',  'account_id', 'account_oid', 'account_name', 'image', 'webp_image', 'videos', 'number_of_images', 'avatar', 'seller_info.full_name', 'seller_info.avatar', 'seller_info.sold_ads', 'seller_info.live_ads', 'has_video', 'company_logo', 'special_display_images', 'special_display', 'state', 'land_feature', 'street_id', 'size_unit', 'property_back_condition', 'property_road_condition', 'unitnumber_display', 'projectimages', 'project_oid', 'projectid', 'orig_list_time', 'streetnumber_display', 'ad_labels', 'label_campaigns', 'pty_jupiter', 'zero_deposit', 'escrow_can_deposit', 'protection_entitlement', 'owner', 'phone_hidden', 'contain_videos', 'type', 'params', 'address', 'location', 'longitude', 'latitude', 'company_ad', 'category', 'area', 'region','body', 'region_v2', 'area_v2', 'ward'], axis=1)

# %%
df_raw.drop(columns=['list_time','subject','price_string','ward_name','street_name'],inplace=True)

# %%
df_raw.rename(columns={
    'subject': 'TenBds',
    'category_name':'TheLoai',
    'area_name':'Huyen',
    'region_name':'Tinh',
    'price':'Gia',
    'rooms':'TongSoPhong',
    'property_legal_document':'GiayTo',
    'ward_name':'Phuong/Xa',
    'price_million_per_m2':'Gia/m2',
    'house_type':'LoaiHinhNhaO',
    'land_type':'LoaiHinhDat',
    'width':'ChieuNgang',
    'length':'ChieuDai',
    'toilets':'PhongVeSinh',
    'floors':'SoTang',
    'furnishing_sell':'NoiThat',
    'living_size':'DienTichSuDung',
    'commercial_type':'LoaiHinhVanPhong',
    'detail_address':'TenDuongCuThe',
    'direction':'HuongCuaChinh',
    'apartment_type':'LoaiHinhCanHo',
    'property_status':'TinhTrangBds',
    'street_number':'SoDuong',
    'block': 'TenPhanKhu/Lo/Block/Thap',
    'floornumber':'TangSo',
    'balconydirection':'HuongBanCong',
    'unitnumber':'MaLo',
    'apartment_feature':'DacDiemCanHoChungCu',
    'size':'DienTich(m2)',
    'street_name':'TenDuong'
    }, inplace=True)

# %%
df_raw.loc[df_raw['GiayTo']==1.0,['GiayTo']]='Đã có sổ'
df_raw.loc[df_raw['GiayTo']==2.0,['GiayTo']]='Đang chờ sổ'
df_raw.loc[df_raw['GiayTo']==3.0,['GiayTo']]='Giấy tờ khác'
df_raw.loc[df_raw['GiayTo']==4.0,['GiayTo']]='Hợp đồng đặt cọc'
df_raw.loc[df_raw['GiayTo']==5.0,['GiayTo']]='Sổ chung'
df_raw.loc[df_raw['GiayTo']==6.0,['GiayTo']]='Sổ hồng riêng'

df_raw.loc[df_raw['LoaiHinhNhaO']==1.0,['LoaiHinhNhaO']]='Nhà mặt phố, mặt tiền'
df_raw.loc[df_raw['LoaiHinhNhaO']==2.0,['LoaiHinhNhaO']]='Nhà ngõ, hẻm'
df_raw.loc[df_raw['LoaiHinhNhaO']==3.0,['LoaiHinhNhaO']]='Nhà phố liền kề'
df_raw.loc[df_raw['LoaiHinhNhaO']==4.0,['LoaiHinhNhaO']]='Nhà biệt thự'

df_raw.loc[df_raw['NoiThat']==1.0,['NoiThat']]='Noi That cao cấp'
df_raw.loc[df_raw['NoiThat']==2.0,['NoiThat']]='Noi That đầy đủ'
df_raw.loc[df_raw['NoiThat']==3.0,['NoiThat']]='Hoàn thiện cơ bản'
df_raw.loc[df_raw['NoiThat']==4.0,['NoiThat']]='Bàn giao thô'

df_raw.loc[df_raw['LoaiHinhVanPhong']==1.0,['LoaiHinhVanPhong']]='Shophouse'
df_raw.loc[df_raw['LoaiHinhVanPhong']==2.0,['LoaiHinhVanPhong']]='Officetel'
df_raw.loc[df_raw['LoaiHinhVanPhong']==3.0,['LoaiHinhVanPhong']]='Văn phòng'
df_raw.loc[df_raw['LoaiHinhVanPhong']==4.0,['LoaiHinhVanPhong']]='Mặt bằng kinh doanh'

df_raw.loc[df_raw['HuongCuaChinh']==1.0,['HuongCuaChinh']]='Đông'
df_raw.loc[df_raw['HuongCuaChinh']==2.0,['HuongCuaChinh']]='Tây'
df_raw.loc[df_raw['HuongCuaChinh']==3.0,['HuongCuaChinh']]='Nam'
df_raw.loc[df_raw['HuongCuaChinh']==4.0,['HuongCuaChinh']]='Bắc'
df_raw.loc[df_raw['HuongCuaChinh']==5.0,['HuongCuaChinh']]='Đông Bắc'
df_raw.loc[df_raw['HuongCuaChinh']==6.0,['HuongCuaChinh']]='Đông Nam'
df_raw.loc[df_raw['HuongCuaChinh']==7.0,['HuongCuaChinh']]='Tây Bắc'
df_raw.loc[df_raw['HuongCuaChinh']==8.0,['HuongCuaChinh']]='Tây Nam'

df_raw.loc[df_raw['HuongBanCong']==1.0,['HuongBanCong']]='Đông'
df_raw.loc[df_raw['HuongBanCong']==2.0,['HuongBanCong']]='Tây'
df_raw.loc[df_raw['HuongBanCong']==3.0,['HuongBanCong']]='Nam'
df_raw.loc[df_raw['HuongBanCong']==4.0,['HuongBanCong']]='Bắc'
df_raw.loc[df_raw['HuongBanCong']==5.0,['HuongBanCong']]='Đông Bắc'
df_raw.loc[df_raw['HuongBanCong']==6.0,['HuongBanCong']]='Đông Nam'
df_raw.loc[df_raw['HuongBanCong']==7.0,['HuongBanCong']]='Tây Bắc'
df_raw.loc[df_raw['HuongBanCong']==8.0,['HuongBanCong']]='Tây Nam'

df_raw.loc[df_raw['LoaiHinhCanHo']==1.0,['LoaiHinhCanHo']]='Chung cư'
df_raw.loc[df_raw['LoaiHinhCanHo']==2.0,['LoaiHinhCanHo']]='Căn hộ dịch vụ, mini'
df_raw.loc[df_raw['LoaiHinhCanHo']==3.0,['LoaiHinhCanHo']]='Duplex'
df_raw.loc[df_raw['LoaiHinhCanHo']==4.0,['LoaiHinhCanHo']]='Penthouse'
df_raw.loc[df_raw['LoaiHinhCanHo']==5.0,['LoaiHinhCanHo']]='Tập thể, cư xá'
df_raw.loc[df_raw['LoaiHinhCanHo']==6.0,['LoaiHinhCanHo']]='Officetel'

df_raw.loc[df_raw['TinhTrangBds']==1.0,['TinhTrangBds']]='Chưa bàn giao'
df_raw.loc[df_raw['TinhTrangBds']==2.0,['TinhTrangBds']]='Đã bàn giao'

df_raw.loc[df_raw['LoaiHinhDat']==1.0,['LoaiHinhDat']]='Đất thổ cư'
df_raw.loc[df_raw['LoaiHinhDat']==2.0,['LoaiHinhDat']]='Đất nền dự án'
df_raw.loc[df_raw['LoaiHinhDat']==3.0,['LoaiHinhDat']]='Đất nông nghiệp'
df_raw.loc[df_raw['LoaiHinhDat']==4.0,['LoaiHinhDat']]='Đất công nghiệp'

df_raw.loc[df_raw['DacDiemCanHoChungCu']==1.0,['DacDiemCanHoChungCu']]='Căn góc'
# Out:
# /tmp/ipykernel_2345/3094607576.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Đã có sổ' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_raw.loc[df_raw['GiayTo']==1.0,['GiayTo']]='Đã có sổ'
# /tmp/ipykernel_2345/3094607576.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Nhà mặt phố, mặt tiền' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_raw.loc[df_raw['LoaiHinhNhaO']==1.0,['LoaiHinhNhaO']]='Nhà mặt phố, mặt tiền'
# /tmp/ipykernel_2345/3094607576.py:13: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Noi That cao cấp' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_raw.loc[df_raw['NoiThat']==1.0,['NoiThat']]='Noi That cao cấp'
# /tmp/ipykernel_2345/3094607576.py:18: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Shophouse' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_raw.loc[df_raw['LoaiHinhVanPhong']==1.0,['LoaiHinhVanPhong']]='Shophouse'
# /tmp/ipykernel_2345/3094607576.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Đông' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_raw.loc[df_raw['HuongCuaChinh']==1.0,['HuongCuaChinh']]='Đông'
# /tmp/ipykernel_2345/3094607576.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Đông' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_raw.loc[df_raw['HuongBanCong']==1.0,['HuongBanCong']]='Đông'
# /tmp/ipykernel_2345/3094607576.py:41: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Chung cư' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_raw.loc[df_raw['LoaiHinhCanHo']==1.0,['LoaiHinhCanHo']]='Chung cư'
# /tmp/ipykernel_2345/3094607576.py:48: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Chưa bàn giao' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_raw.loc[df_raw['TinhTrangBds']==1.0,['TinhTrangBds']]='Chưa bàn giao'
# /tmp/ipykernel_2345/3094607576.py:51: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Đất thổ cư' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_raw.loc[df_raw['LoaiHinhDat']==1.0,['LoaiHinhDat']]='Đất thổ cư'
# /tmp/ipykernel_2345/3094607576.py:56: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Căn góc' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_raw.loc[df_raw['DacDiemCanHoChungCu']==1.0,['DacDiemCanHoChungCu']]='Căn góc'

# %%
# for i in df_raw.columns:
#     print(df_raw[i].value_counts())

# %%
df_raw.select_dtypes(['object']).describe()
# Out:
#        TheLoai              Huyen            Tinh    GiayTo     LoaiHinhNhaO  \
# count    40056              40055           40056     39759            27618
# unique       4                 58               3         6                4
# top      Nhà ở  Thành phố Thủ Đức  Tp Hồ Chí Minh  Đã có sổ  Nhà phố liền kề
# freq     27619               2763           19210     33669            18479
#
#             location_id                  unique_street_id is_main_street  \
# count             10017                             10066          10066
# unique             3975                              3256              1
# top     osm:W1239581819  81e3525992ebb87805bcfcc4adf1bd29          False
# freq                 59                                81          10066
#
#        HuongCuaChinh          NoiThat  \
# count          10520            18616
# unique             8                4
# top         Đông Nam  Noi That đầy đủ
# freq            2158             9147
#
#                                             TenDuongCuThe LoaiHinhCanHo  \
# count                                                3710          5296
# unique                                               1114             6
# top     Xã Đa Tốn, Kiêu Kỵ, Dương Xá và một phần thị t...      Chung cư
# freq                                                  349          4624
#
#        TinhTrangBds TenPhanKhu/Lo/Block/Thap HuongBanCong  MaLo LoaiHinhDat  \
# count          5296                     1795         1521  1488        6637
# unique            2                     1079            8   774           4
# top     Đã bàn giao                        A     Đông Nam     1  Đất thổ cư
# freq           4140                      131          538    60        5765
#
#        SoDuong DacDiemCanHoChungCu     LoaiHinhVanPhong
# count     4796                 897                  504
# unique    2500                   1                    4
# top      số 88             Căn góc  Mặt bằng kinh doanh
# freq        94                 897                  375

# %%
df_c = df_raw.copy()

# %%
perce_null = df_c.isna().sum()*100/df_c.shape[0]
df_c= df_c.drop(columns=  perce_null[perce_null.values > 55].index )
# Out:
# TheLoai                     0.000000
# Huyen                       0.002497
# Tinh                        0.000000
# Gia                         0.000000
# TongSoPhong                17.827541
# GiayTo                      0.741462
# DienTich(m2)                0.000000
# LoaiHinhNhaO               31.051528
# location_id                74.992510
# unique_street_id           74.870182
# is_main_street             74.870182
# HuongCuaChinh              73.736769
# PhongVeSinh                39.115239
# SoTang                     53.852107
# NoiThat                    53.525065
# DienTichSuDung             63.353805
# TenDuongCuThe              90.737967
# LoaiHinhCanHo              86.778510
# TinhTrangBds               86.778510
# TenPhanKhu/Lo/Block/Thap   95.518774
# TangSo                     97.046635
# HuongBanCong               96.202816
# MaLo                       96.285201
# ChieuNgang                 41.264729
# ChieuDai                   49.188636
# LoaiHinhDat                83.430697
# SoDuong                    88.026763
# DacDiemCanHoChungCu        97.760635
# LoaiHinhVanPhong           98.741762
# dtype: float64

# %%
df_c.select_dtypes(['object']).describe()
# Out:
#        TheLoai              Huyen            Tinh    GiayTo     LoaiHinhNhaO  \
# count    40854              40853           40854     39074            26542
# unique       5                 59               3         6                4
# top      Nhà ở  Thành phố Thủ Đức  Tp Hồ Chí Minh  Đã có sổ  Nhà phố liền kề
# freq     26542               3337           19798     33006            17279
#
#                 NoiThat
# count             18543
# unique                4
# top     Noi That đầy đủ
# freq               9035

# %%
df_c.describe()
# Out:
#                       Gia  TongSoPhong  DienTich(m2)    ChieuNgang  \
# count        40854.000000 32737.000000  40853.000000  23631.000000
# mean    7894028777.748519     3.545804    129.764259     15.464205
# std    23489169657.313602     2.047753   1732.622733    922.677118
# min         400000.000000     1.000000      1.000000      1.200000
# 25%     2700000000.000000     2.000000     45.000000      4.000000
# 50%     4500000000.000000     3.000000     64.000000      4.800000
# 75%     7500000000.000000     4.000000     95.000000      5.401450
# max   999999999999.000000    11.000000 260000.000000 120797.000000
#
#           ChieuDai  PhongVeSinh       SoTang
# count 20391.000000 24591.000000 18388.000000
# mean     19.299993     3.127852     3.701708
# std     147.506917     1.598266     5.375369
# min       1.000000     1.000000     1.000000
# 25%      11.000000     2.000000     2.000000
# 50%      15.000000     3.000000     3.000000
# 75%      20.000000     4.000000     5.000000
# max   13947.000000     7.000000   421.000000

# %%
fr =df_c.copy()
# fr['log_price']=np.log1p(fr['Giá'])
def scatt(x,fig):
    plt.subplot(5,3,fig)
    # plt.scatter(fr[x],fr['log_price'])
    plt.scatter(fr[x],fr['Gia'])
    plt.xlabel(x)
    plt.ylabel('price')

# %%
plt.figure(figsize=(15,20))
scatt('TongSoPhong',1)
scatt('PhongVeSinh',2)
scatt('SoTang',3)
scatt('ChieuNgang',4)
scatt('ChieuDai',5)
# scatt('DienTichSuDung',6)
scatt('DienTich(m2)',7)

# %% [markdown]
# #### FIll catefory and numeric misssing value

# %%
q3_gia=df_c['Gia'].quantile(0.98)
df_c = df_c[(df_c['Gia'] < q3_gia)]

# %%
q3=df_c['DienTich(m2)'].quantile(0.99)
df_c= df_c[df_c['DienTich(m2)'] <=q3]

# %%
df_c = df_c[df_c['ChieuNgang'] <= 60000]

# %%
df_c = df_c[df_c['ChieuDai'] <= 2000]

# %%
# Fill the missing values with mean values
for column in [
'ChieuNgang',
'ChieuDai',
'DienTich(m2)'
]:
    df_c[column].fillna(value=df_c[column].mean(),inplace=True)
# Out:
# /tmp/ipykernel_2345/1457518611.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_c[column].fillna(value=df_c[column].mean(),inplace=True)

# %%
for column in [
'TongSoPhong',
'Huyen',
'GiayTo',
'LoaiHinhNhaO',
'PhongVeSinh',
'NoiThat',
'SoTang',

]:
    df_c[column].fillna(value=df_c[column].mode()[0],inplace=True)
# Out:
# /tmp/ipykernel_2345/3854864641.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_c[column].fillna(value=df_c[column].mode()[0],inplace=True)

# %%
df_c.isna().sum()*100/df_c.shape[0]
# fr.shape
# Out:
# TheLoai        0.000000
# Huyen          0.000000
# Tinh           0.000000
# Gia            0.000000
# TongSoPhong    0.000000
# GiayTo         0.000000
# DienTich(m2)   0.000000
# LoaiHinhNhaO   0.000000
# PhongVeSinh    0.000000
# SoTang         0.000000
# NoiThat        0.000000
# ChieuNgang     0.000000
# ChieuDai       0.000000
# dtype: float64

# %%
fr2 =df_c.copy()
# fr['log_price']=np.log1p(fr['Giá'])
def scatt(x,fig):
    plt.subplot(5,3,fig)
    # plt.scatter(fr[x],fr['log_price'])
    plt.scatter(fr2[x],fr2['Gia'])
    plt.xlabel(x)
    plt.ylabel('price')

# %%
plt.figure(figsize=(15,20))
scatt('TongSoPhong',1)
scatt('PhongVeSinh',2)
scatt('SoTang',3)
scatt('ChieuNgang',4)
scatt('ChieuDai',5)
# scatt('DienTichSuDung',6)
scatt('DienTich(m2)',7)

# %%
df_c2=df_c.copy()

# %%
def barfunction(tinh):
    if tinh!='':
        df_tinh= df_c2[df_c2['Tinh']==tinh]
        frame = df_tinh.copy()
    else :
        frame =df_c2.copy()
    k = frame.groupby('Huyen')['Gia'].mean().reset_index(name='avg_price')
    frame = frame.merge(k,how='inner',on='Huyen')
    plt.figure(figsize=(15,8))
    plt.xticks(rotation=80)
    plt.ylabel('USD')
    plt.bar(x='Huyen', height = 'avg_price', 
    data=frame)
    # plt.ticklabel_format(style='plain',axis='y')

# %%
frame =df_c2.copy()
k = frame.groupby('Tinh')['Gia'].mean().reset_index(name='avg_price')
frame = frame.merge(k,how='inner',on='Tinh')
plt.figure(figsize=(15,16))
plt.xticks(rotation=80)
plt.ylabel('USD')
plt.bar(x='Tinh', height = 'avg_price', data=frame)
    # plt.ticklabel_format(style='plain',axis='y')
# Out:
# <BarContainer object of 19618 artists>

# %%
barfunction('Hà Nội')

# %%
barfunction('Tp Hồ Chí Minh')

# %%
barfunction('Đà Nẵng')

# %%
# TheLoai	Huyen	Tinh	GiayTo	LoaiHinhNhaO	NoiThat

# %%
def analysis(catrgorial):
    frame=df_c2.copy()
    k = frame.groupby(catrgorial)['Gia'].mean().reset_index(name='avg_price')
    frame = frame.merge(k,how='inner',on=catrgorial)
    plt.figure(figsize=(15,8))
    plt.xticks(rotation=80)
    plt.ylabel('USD')
    plt.bar(x=catrgorial, height = 'avg_price', data=frame)

# %%
# plt.figure(figsize=(15,16))
# analysis('NoiThat')

# %%
# plt.figure(figsize=(15,16))
# analysis('LoaiHinhNhaO')

# %%
# plt.figure(figsize=(15,16))
# analysis('GiayTo')

# %%
# TongSoPhong	DienTich(m2)	ChieuNgang	ChieuDai	PhongVeSinh	SoTang	DienTichSuDung	TangSo
# TheLoai	Huyen	Tinh	GiayTo	LoaiHinhNhaO	NoiThat

# %%
plt.figure(figsize=(16,8))
sns.boxplot(data=df_c2,x='TheLoai',y='Gia')
plt.title('Thể loại nhà với giá nhà')
plt.xlabel('Thể loại nhà')
plt.ylabel('Giá')
plt.show()

plt.figure(figsize=(16,8))
sns.boxplot(data=df_c2,x='NoiThat',y='Gia')
plt.title('Tình trạng nội thất và giá nhà')
plt.xlabel('Tình trạng nội thất')
plt.ylabel('Giá')
plt.show()

plt.figure(figsize=(16,8))
sns.boxplot(data=df_c2,x='LoaiHinhNhaO',y='Gia')
plt.title('Loại hình nhà ở với giá nhà')
plt.xlabel('Loại hình nhà ở')
plt.ylabel('Giá')
plt.show()

plt.figure(figsize=(16,8))
sns.boxplot(data=df_c2,x='GiayTo',y='Gia')
plt.title('Tình trạng giấy tờ với giá nhà')
plt.xlabel('Tình trạng giấy tờ')
plt.ylabel('Giá')
plt.show()

# %%
# df_c2[df_c2['Gia'] > 1490416]
# df_c2.drop([4880],inplace=True)
# df_c2.columns
# df_c2.dtypes(inc['float64'])

sns.heatmap(data=df_c2.select_dtypes(include=['float64']).corr(),annot=True)
# Out:
# <Axes: >
